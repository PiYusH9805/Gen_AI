# %%
from langchain_groq import ChatGroq

from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
import os
load_dotenv()
model = ChatGroq(
    model="llama-3.1-8b-instant",
    api_key=os.getenv("GROQ_API_KEY")
)

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': '**Title:** The Rise of AI in India: Trends, Opportunities, and Challenges\n\n**I. Introduction**\n\n* Brief overview of the growing importance of AI in India\n* Statistics on the current state of AI adoption in India\n* Thesis statement: The rise of AI in India is transforming various industries and creating new opportunities, but also poses significant challenges that need to be addressed.\n\n**II. Historical Background of AI in India**\n\n* Early beginnings of AI research in India (1960s-1980s)\n* Key milestones in AI development in India (1990s-2000s)\n* Current state of AI research and development in India\n\n**III. Current Trends in AI Adoption in India**\n\n* Overview of the current AI landscape in India (AI adoption rates, industry focus areas, etc.)\n* Analysis of the key drivers of AI adoption in India (government initiatives, private sector investment, etc.)\n* Examples of successful AI adoption stories in India (e.g., AI-powered healthcare, e-commerce, finance, etc.)\n\n**IV. Impact of AI on Indian Industries**\n\n* Overview of the impact of AI on various Indian industries (e.g., healthcare, finance, e-commerce, education, etc.)\n* Analysis of the benefits and challenges of AI adoption in each industry\n* Examples of successful AI applications in each industry\n\n**V. Opportunities and Challenges of AI in India**\n\n* Overview of the opportunities created by AI in India (job creation, economic growth, etc.)\n* Analysis of the challenges posed by AI in India (job displacement, data privacy, etc.)\n* Discussion of the need for a strategic approach to AI adoption in India\n\n**VI. AI Education and Skills in India**\n\n* Overview of the current state of AI education and skills in India\n* Analysis of the need for upskilling and reskilling in the AI era\n* Discussion of initiatives to promote AI education and skills in India\n\n**VII. Government Initiatives for AI in India**\n\n* Overview of government initiatives for AI in India (e.g., AI for All, Digital India, etc.)\n* Analysis of the role of the government in promoting AI adoption in India\n* Discussion of the need for a supportive ecosystem for AI adoption in India\n\n**VIII. Conclusion**\n\n* Recap of the rise of AI in India\n* Discussion of the need for a strategic approach to AI adoption in India\n* Final thoughts on the future of AI in India.\n\n**IX. Recommendations**\n\n* Call to action for organizations, policymakers, and individuals to work together to promote AI adoption in India\n* Suggestions for future research and development in AI in India.\n\n**X. References**\n\n* List of sources used in the research.\n\n**XI. Appendices**\n\n* Additional information or data that is not essential to the main narrative.\n\nThis outline provides a comprehensive structure for a blog on the rise of AI in India, covering the historical background, current trends, impact on industries, opportunities and challenges, education and skills, government initiatives, and conclusions.', 'content': '**The Rise of AI in India: Trends, Opportunities, and Challenges**\n\n**I. Introduction**\n\nThe Indian economy is rapidly embracing artificial intelligence (AI), and the nation is witnessing a significant transformation in various sectors. According to a report by MarketsandMarkets, the Indian AI market is projected to reach $7.8 billion by 2026, growing at a Compound Annual Growth Rate (CAGR) of 33.6% during the forecast period. This growth is driven by the increasing adoption of AI in industries such as healthcare, finance, e-commerce, and education.\n\nThe Indian government has also taken initiatives to promote AI adoption in the country. The Digital India program, launched in 2015, aims to make India a digital society. Additionally, the government has established the Artificial Intelligence Council to promote AI adoption in various sectors. These efforts have led to a surge in AI adoption in India, with the nation now being considered on ...

# %%
print(final_state['outline'])
# Out:
# **Title:** The Rise of AI in India: Trends, Opportunities, and Challenges
#
# **I. Introduction**
#
# * Brief overview of the growing importance of AI in India
# * Statistics on the current state of AI adoption in India
# * Thesis statement: The rise of AI in India is transforming various industries and creating new opportunities, but also poses significant challenges that need to be addressed.
#
# **II. Historical Background of AI in India**
#
# * Early beginnings of AI research in India (1960s-1980s)
# * Key milestones in AI development in India (1990s-2000s)
# * Current state of AI research and development in India
#
# **III. Current Trends in AI Adoption in India**
#
# * Overview of the current AI landscape in India (AI adoption rates, industry focus areas, etc.)
# * Analysis of the key drivers of AI adoption in India (government initiatives, private sector investment, etc.)
# * Examples of successful AI adoption stories in India (e.g., AI-powered healthcare, e-commerce, finance, etc.)
#
# **IV. Impact of AI on Indian Industries**
#
# * Overview of the impact of AI on various Indian industries (e.g., healthcare, finance, e-commerce, education, etc.)
# * Analysis of the benefits and challenges of AI adoption in each industry
# * Examples of successful AI applications in each industry
#
# **V. Opportunities and Challenges of AI in India**
#
# * Overview of the opportunities created by AI in India (job creation, economic growth, etc.)
# * Analysis of the challenges posed by AI in India (job displacement, data privacy, etc.)
# * Discussion of the need for a strategic approach to AI adoption in India
#
# **VI. AI Education and Skills in India**
#
# * Overview of the current state of AI education and skills in India
# * Analysis of the need for upskilling and reskilling in the AI era
# * Discussion of initiatives to promote AI education and skills in India
#
# **VII. Government Initiatives for AI in India**
#
# * Overview of government initiatives for AI in India (e.g., AI for All, Digital India, etc.)
# * Analysis of the role of the government in promoting AI adoption in India
# * Discussion of the need for a supportive ecosystem for AI adoption in India
#
# **VIII. Conclusion**
#
# * Recap of the rise of AI in India
# * Discussion of the need for a strategic approach to AI adoption in India
# * Final thoughts on the future of AI in India.
#
# **IX. Recommendations**
#
# * Call to action for organizations, policymakers, and individuals to work together to promote AI adoption in India
# * Suggestions for future research and development in AI in India.
#
# **X. References**
#
# * List of sources used in the research.
#
# **XI. Appendices**
#
# * Additional information or data that is not essential to the main narrative.
#
# This outline provides a comprehensive structure for a blog on the rise of AI in India, covering the historical background, current trends, impact on industries, opportunities and challenges, education and skills, government initiatives, and conclusions.

# %%
print(final_state['content'])
# Out:
# **The Rise of AI in India: Trends, Opportunities, and Challenges**
#
# **I. Introduction**
#
# The Indian economy is rapidly embracing artificial intelligence (AI), and the nation is witnessing a significant transformation in various sectors. According to a report by MarketsandMarkets, the Indian AI market is projected to reach $7.8 billion by 2026, growing at a Compound Annual Growth Rate (CAGR) of 33.6% during the forecast period. This growth is driven by the increasing adoption of AI in industries such as healthcare, finance, e-commerce, and education.
#
# The Indian government has also taken initiatives to promote AI adoption in the country. The Digital India program, launched in 2015, aims to make India a digital society. Additionally, the government has established the Artificial Intelligence Council to promote AI adoption in various sectors. These efforts have led to a surge in AI adoption in India, with the nation now being considered one of the fastest-growing AI markets globally.
#
# However, the rise of AI in India also poses significant challenges that need to be addressed. The increased adoption of AI may lead to job displacement, and there is a need for upskilling and reskilling of the workforce to make them AI-ready. Furthermore, there are concerns about data privacy and security, and the government must ensure that the benefits of AI are equitably distributed across the society.
#
# **II. Historical Background of AI in India**
#
# The history of AI research in India dates back to the 1960s, when the Indian government established the Indian Institute of Technology (IIT) in Kanpur. The IIT Kanpur was one of the first institutions in India to start AI research, and it has since become a hub for AI research and development in the country.
#
# In the 1990s and 2000s, India saw significant growth in AI research, with the establishment of institutions such as the Indian Institute of Science (IISc) and the International Institute of Information Technology (IIIT). These institutions have played a crucial role in advancing AI research in India and have produced many notable AI researchers and scientists.
#
# Today, India is home to a vibrant AI research community, with many institutions and organizations engaging in AI research and development. The Indian government has also established several initiatives to promote AI adoption in various sectors, including the AI for All program, which aims to promote AI adoption in industries such as healthcare, finance, and education.
#
# **III. Current Trends in AI Adoption in India**
#
# The current AI landscape in India is characterized by rapid adoption across various sectors. According to a report by PwC, the adoption of AI in India is driven by the increasing demand for automation, improved customer experience, and enhanced operational efficiency.
#
# The Indian government has also played a significant role in promoting AI adoption in the country. The Digital India program, launched in 2015, aims to make India a digital society and has led to the adoption of AI in various sectors, including healthcare, finance, and education.
#
# Several successful AI adoption stories in India include:
#
# * **AI-powered healthcare**: The AI-powered healthcare platform, Medibuddy, has been adopted by several hospitals in India to improve patient care and reduce healthcare costs.
# * **E-commerce**: The AI-powered e-commerce platform, Flipkart, has been adopted by several retailers in India to improve customer experience and enhance operational efficiency.
# * **Finance**: The AI-powered finance platform, Paytm, has been adopted by several financial institutions in India to improve customer experience and enhance operational efficiency.
#
# **IV. Impact of AI on Indian Industries**
#
# The impact of AI on various Indian industries is significant, and it has transformed the way businesses operate in these sectors. Some of the key benefits of AI adoption in these sectors include:
#
# * **Healthcare**: AI has improved patient care and reduced healthcare costs in India. AI-powered healthcare platforms have also improved the speed and accuracy of diagnosis.
# * **Finance**: AI has improved customer experience and enhanced operational efficiency in the finance sector. AI-powered finance platforms have also improved the speed and accuracy of transactions.
# * **E-commerce**: AI has improved customer experience and enhanced operational efficiency in the e-commerce sector. AI-powered e-commerce platforms have also improved the speed and accuracy of delivery.
#
# However, the adoption of AI in these sectors also poses significant challenges, including job displacement and data privacy and security concerns.
#
# **V. Opportunities and Challenges of AI in India**
#
# The rise of AI in India presents several opportunities, including:
#
# * **Job creation**: AI has created new job opportunities in India, particularly in the fields of AI development, deployment, and maintenance.
# * **Economic growth**: AI has the potential to drive economic growth in India, particularly in the sectors of healthcare, finance, and e-commerce.
# * **Improved customer experience**: AI has improved customer experience in various sectors, including healthcare, finance, and e-commerce.
#
# However, the adoption of AI in India also poses significant challenges, including:
#
# * **Job displacement**: AI has the potential to displace jobs in India, particularly in the sectors of healthcare, finance, and e-commerce.
# * **Data privacy and security**: AI has raised concerns about data privacy and security in India, particularly in the sectors of healthcare, finance, and e-commerce.
# * **Equitable distribution of benefits**: The benefits of AI adoption in India need to be equitably distributed across the society, particularly in the sectors of healthcare, finance, and e-commerce.
#
# **VI. AI Education and Skills in India**
#
# The current state of AI education and skills in India is a concern, particularly in the sectors of healthcare, finance, and e-commerce. According to a report by the World Economic Forum, India is facing a significant shortage of AI skills, particularly in the areas of data science and machine learning.
#
# There is a need for upskilling and reskilling of the workforce in India to make them AI-ready. The government, industry, and academia must work together to promote AI education and skills in India.
#
# Several initiatives have been launched to promote AI education and skills in India, including:
#
# * **AI for All program**: The AI for All program aims to promote AI adoption in industries such as healthcare, finance, and education.
# * **Digital India program**: The Digital India program aims to make India a digital society and has led to the adoption of AI in various sectors.
# * **AI certification programs**: Several AI certification programs have been launched in India to promote AI education and skills.
#
# **VII. Government Initiatives for AI in India**
#
# The Indian government has taken several initiatives to promote AI adoption in India, including:
#
# * **AI for All program**: The AI for All program aims to promote AI adoption in industries such as healthcare, finance, and education.
# * **Digital India program**: The Digital India program aims to make India a digital society and has led to the adoption of AI in various sectors.
# * **AI Council**: The AI Council has been established to promote AI adoption in various sectors and to provide guidance on AI-related issues.
#
# **VIII. Conclusion**
#
# The rise of AI in India is transforming various industries and creating new opportunities. However, the adoption of AI in India also poses significant challenges that need to be addressed. The government, industry, and academia must work together to promote AI education and skills in India and to ensure that the benefits of AI adoption are equitably distributed across the society.
#
# **IX. Recommendations**
#
# * **Upskilling and reskilling of workforce**: The government, industry, and academia must work together to promote AI education and skills in India and to upskill and reskill the workforce to make them AI-ready.
# * **Equitable distribution of benefits**: The benefits of AI adoption in India need to be equitably distributed across the society, particularly in the sectors of healthcare, finance, and e-commerce.
# * **Data privacy and security**: The government must ensure that data privacy and security concerns are addressed in the adoption of AI in India.
#
# **X. References**
#
# * **MarketsandMarkets**: "India AI Market to Reach $7.8 Billion by 2026"
# * **PwC**: "The AI Effect: How AI is Transforming Business in India"
# * **World Economic Forum**: "The Future of Jobs Report 2018"
#
# **XI. Appendices**
#
# * **AI adoption rates in India**: A table showing the adoption rates of AI in various sectors in India.
# * **AI education and skills in India**: A table showing the current state of AI education and skills in India.
